# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
package_path = '/content/drive/MyDrive/Colab\ Notebooks/DLBasics2024_colab/final/dl_lecture_competition_pub/my-site-packages'
package_path_str = '/content/drive/MyDrive/Colab Notebooks/DLBasics2024_colab/final/dl_lecture_competition_pub/my-site-packages'
sys.path.append(package_path_str)
sys.path.append('/content/drive/MyDrive/Colab Notebooks/DLBasics2024_colab/final/dl_lecture_competition_pub')
sys.path.append('/content/drive/MyDrive/Colab Notebooks/DLBasics2024_colab/final/dl_lecture_competition_pub/src')
# Out:
# Mounted at /content/drive

# %%
# !pip install torchmetrics
# !pip install hydra-core
# !pip install wandb
# !pip install einops
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.8/868.8 kB 11.4 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %%
# !python /content/drive/MyDrive/Colab\ Notebooks/DLBasics2024_colab/final/dl_lecture_competition_pub/main.py
# Out:
# Epoch 1/30
# Train: 100% 514/514 [00:45<00:00, 11.42it/s]
# Validation: 100% 129/129 [00:07<00:00, 16.90it/s]
# Epoch 1/30 | train loss: 9.622 | train acc: 0.006 | val loss: 9.418 | val acc: 0.006
# New best.
# Epoch 2/30
# Train: 100% 514/514 [00:43<00:00, 11.71it/s]
# Validation: 100% 129/129 [00:07<00:00, 17.07it/s]
# Epoch 2/30 | train loss: 9.237 | train acc: 0.011 | val loss: 9.110 | val acc: 0.009
# New best.
# Epoch 3/30
# Train: 100% 514/514 [00:44<00:00, 11.63it/s]
# Validation: 100% 129/129 [00:07<00:00, 17.20it/s]
# Epoch 3/30 | train loss: 8.948 | train acc: 0.015 | val loss: 8.867 | val acc: 0.011
# New best.
# Epoch 4/30
# Train: 100% 514/514 [00:44<00:00, 11.61it/s]
# Validation: 100% 129/129 [00:07<00:00, 17.27it/s]
# Epoch 4/30 | train loss: 8.718 | train acc: 0.018 | val loss: 8.670 | val acc: 0.012
# New best.
# Epoch 5/30
# Train: 100% 514/514 [00:44<00:00, 11.62it/s]
# Validation: 100% 129/129 [00:07<00:00, 17.00it/s]
# ...
